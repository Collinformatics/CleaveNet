# %% [markdown]
# # CleaveNet
#
# In this notebook we will overview how to approach the following topics:
#
# * Installation
# * Predicting substrate cleavage with CleaveNet
# * Unconditional substrate generation
#
# ## Installation
#
# To download and run our code, first open this notebook in a clean conda environment. We recommend creating it with python 3.8. You can do so by running conda create --name evodiff python=3.8. In that new environment, to download our code, run:

# %%
# !pwd # you should be in the cleavenet directory (outside of notebooks)
# !pip install tensorflow # will compile on CPU
# !pip install cleavenet
# Out:
# /Users/ca34522/cleavenet
# Requirement already satisfied: tensorflow in ./.venv/lib/python3.10/site-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in ./.venv/lib/python3.10/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./.venv/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in ./.venv/lib/python3.10/site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in ./.venv/lib/python3.10/site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in ./.venv/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in ./.venv/lib/python3.10/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./.venv/lib/python3.10/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in ./.venv/lib/python3.10/site-packages (from tensorflow) (26.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in ./.venv/lib/python3.10/site-packages (from tensorflow) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in ./.venv/lib/python3.10/site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.10/site-packages (from tensorflow) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in ./.venv/lib/python3.10/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./.venv/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in ./.venv/lib/python3.10/site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in ./.venv/lib/python3.10/site-packages (from tensorflow) (2.1.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./.venv/lib/python3.10/site-packages (from tensorflow) (1.78.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in ./.venv/lib/python3.10/site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in ./.venv/lib/python3.10/site-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in ./.venv/lib/python3.10/site-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in ./.venv/lib/python3.10/site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in ./.venv/lib/python3.10/site-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./.venv/lib/python3.10/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (2026.1.4)
# Requirement already satisfied: markdown>=2.6.8 in ./.venv/lib/python3.10/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.venv/lib/python3.10/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.venv/lib/python3.10/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./.venv/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: rich in ./.venv/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow) (14.3.2)
# Requirement already satisfied: namex in ./.venv/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in ./.venv/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow) (0.18.0)
# Requirement already satisfied: markupsafe>=2.1.1 in ./.venv/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Requirement already satisfied: cleavenet in ./.venv/lib/python3.10/site-packages (0.1.2)
# Requirement already satisfied: jellyfish==1.1.3 in ./.venv/lib/python3.10/site-packages (from cleavenet) (1.1.3)
# Requirement already satisfied: logomaker==0.8.6 in ./.venv/lib/python3.10/site-packages (from cleavenet) (0.8.6)
# Requirement already satisfied: matplotlib==3.10.0 in ./.venv/lib/python3.10/site-packages (from cleavenet) (3.10.0)
# Requirement already satisfied: numpy in ./.venv/lib/python3.10/site-packages (from cleavenet) (2.0.2)
# Requirement already satisfied: pandas==2.2.3 in ./.venv/lib/python3.10/site-packages (from cleavenet) (2.2.3)
# Requirement already satisfied: scikit-learn==1.6.1 in ./.venv/lib/python3.10/site-packages (from cleavenet) (1.6.1)
# Requirement already satisfied: scipy==1.15.1 in ./.venv/lib/python3.10/site-packages (from cleavenet) (1.15.1)
# Requirement already satisfied: seaborn==0.13.2 in ./.venv/lib/python3.10/site-packages (from cleavenet) (0.13.2)
# Requirement already satisfied: setuptools==75.8.0 in ./.venv/lib/python3.10/site-packages (from cleavenet) (75.8.0)
# Requirement already satisfied: tensorflow==2.18.0 in ./.venv/lib/python3.10/site-packages (from cleavenet) (2.18.0)
# Requirement already satisfied: tqdm==4.67.1 in ./.venv/lib/python3.10/site-packages (from cleavenet) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.10/site-packages (from matplotlib==3.10.0->cleavenet) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.10/site-packages (from matplotlib==3.10.0->cleavenet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.10/site-packages (from matplotlib==3.10.0->cleavenet) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.10/site-packages (from matplotlib==3.10.0->cleavenet) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.10/site-packages (from matplotlib==3.10.0->cleavenet) (26.0)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.10/site-packages (from matplotlib==3.10.0->cleavenet) (12.1.1)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.10/site-packages (from matplotlib==3.10.0->cleavenet) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.10/site-packages (from matplotlib==3.10.0->cleavenet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.10/site-packages (from pandas==2.2.3->cleavenet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.10/site-packages (from pandas==2.2.3->cleavenet) (2025.3)
# Requirement already satisfied: joblib>=1.2.0 in ./.venv/lib/python3.10/site-packages (from scikit-learn==1.6.1->cleavenet) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.venv/lib/python3.10/site-packages (from scikit-learn==1.6.1->cleavenet) (3.6.0)
# Requirement already satisfied: absl-py>=1.0.0 in ./.venv/lib/python3.10/site-packages (from tensorflow==2.18.0->cleavenet) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./.venv/lib/python3.10/site-packages (from tensorflow==2.18.0->cleavenet) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in ./.venv/lib/python3.10/site-packages (from tensorflow==2.18.0->cleavenet) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in ./.venv/lib/python3.10/site-packages (from tensorflow==2.18.0->cleavenet) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in ./.venv/lib/python3.10/site-packages (from tensorflow==2.18.0->cleavenet) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in ./.venv/lib/python3.10/site-packages (from tensorflow==2.18.0->cleavenet) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./.venv/lib/python3.10/site-packages (from tensorflow==2.18.0->cleavenet) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in ./.venv/lib/python3.10/site-packages (from tensorflow==2.18.0->cleavenet) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in ./.venv/lib/python3.10/site-packages (from tensorflow==2.18.0->cleavenet) (2.32.5)
# Requirement already satisfied: six>=1.12.0 in ./.venv/lib/python3.10/site-packages (from tensorflow==2.18.0->cleavenet) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./.venv/lib/python3.10/site-packages (from tensorflow==2.18.0->cleavenet) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in ./.venv/lib/python3.10/site-packages (from tensorflow==2.18.0->cleavenet) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in ./.venv/lib/python3.10/site-packages (from tensorflow==2.18.0->cleavenet) (2.1.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./.venv/lib/python3.10/site-packages (from tensorflow==2.18.0->cleavenet) (1.78.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in ./.venv/lib/python3.10/site-packages (from tensorflow==2.18.0->cleavenet) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in ./.venv/lib/python3.10/site-packages (from tensorflow==2.18.0->cleavenet) (3.12.1)
# Requirement already satisfied: h5py>=3.11.0 in ./.venv/lib/python3.10/site-packages (from tensorflow==2.18.0->cleavenet) (3.15.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in ./.venv/lib/python3.10/site-packages (from tensorflow==2.18.0->cleavenet) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./.venv/lib/python3.10/site-packages (from tensorflow==2.18.0->cleavenet) (0.37.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.18.0->cleavenet) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.18.0->cleavenet) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.18.0->cleavenet) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.18.0->cleavenet) (2026.1.4)
# Requirement already satisfied: markdown>=2.6.8 in ./.venv/lib/python3.10/site-packages (from tensorboard<2.19,>=2.18->tensorflow==2.18.0->cleavenet) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.venv/lib/python3.10/site-packages (from tensorboard<2.19,>=2.18->tensorflow==2.18.0->cleavenet) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.venv/lib/python3.10/site-packages (from tensorboard<2.19,>=2.18->tensorflow==2.18.0->cleavenet) (3.1.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./.venv/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow==2.18.0->cleavenet) (0.46.3)
# Requirement already satisfied: rich in ./.venv/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow==2.18.0->cleavenet) (14.3.2)
# Requirement already satisfied: namex in ./.venv/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow==2.18.0->cleavenet) (0.1.0)
# Requirement already satisfied: optree in ./.venv/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow==2.18.0->cleavenet) (0.18.0)
# Requirement already satisfied: markupsafe>=2.1.1 in ./.venv/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow==2.18.0->cleavenet) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow==2.18.0->cleavenet) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow==2.18.0->cleavenet) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow==2.18.0->cleavenet) (0.1.2)

# %%
import os 
import csv
import pandas as pd

import cleavenet 
from cleavenet.models import predict_scores_simple #, generate_substrates_simple
from cleavenet.utils import mmps
from cleavenet.analysis import calc_selectivity_score

# %% [markdown]
# ## CleaveNet predictions
#
# The following code demonstrates how to predict Z-scores for a custom set of substrates.
#
# Change the substrates in the following cell to the sequences you desire. For most cases the default settings `save_dir`, and `model_architecture` should be fine. In some cases we found the LSTM model to extrapolate better to unseen data. You can employ this model by setting  `model_architecture = 'lstm'`

# %%
## ---- Inputs to change ----- ### 

# replace the following example substrates with a list of your substrates 
substrates = [
    '--AAALS---',
    'FMPLNFTASG',
    'LGPYAMTSRG',
    'AARFKKFATE',
    'AKPNRLVNSY',
    'YGPRAVTASG',
    'SGPRAFWGTA'
    ]
# substrates = [
#     'GPAPELLGGG',
#     'GRPLALWRSG',
#     'GPPLKLMHSG',
#     'GPVLALMLMG',
#     'GALSLGTQGG',
#     'GPLSLGTQGG',
#     'GVEALYLVCG',
#     'GAPPPVVLLG',
#     'GAATGLYVDG',
#     'GVAQDLNAPG',
#     'GEPTGLEATG'
#     ]
substrates = [
    '-DALCLALV-',
    '-DSQVMMLS-',
    '-FVLGLMLA-',
    '-TVLALPLS-',
    '-FGPLELVG-',
    '-VIMLLSVD-',
    '-LYMLSLSV-',
    '-MMMAISMA-',
    '-IMMMISVD-',
    ]

# The default prediction settings should work for most cases

save_dir = 'outputs/' # where to save outputs 
model_architecture = 'transformer' # 'lstm' # 'transformer' or 'lstm'
checkpoint_dir = 'weights/' # relative path to weights folder

# %% [markdown]
# The following cell runs predictions on the sequences provided, and saves them in `pred_zscores`. `unc_scores` contains uncertainty values for each prediction, as described in the paper

# %%
# Run this cell as is; there will be lots of print statements, you can ignore them 
pred_zscores, unc_scores = predict_scores_simple(substrates, 
                                                 checkpoint_dir=checkpoint_dir, 
                                                 save_dir=save_dir, 
                                                 model_architecture=model_architecture)
# Out:
# Splits previously written to file
# Vocab:
#  {'-': 0, 'A': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'H': 7, 'I': 8, 'K': 9, 'L': 10, 'M': 11, 'N': 12, 'P': 13, 'Q': 14, 'R': 15, 'S': 16, 'T': 17, 'V': 18, 'W': 19, 'Y': 20, '!': 21}
# 7 --AAALS---
# Running 0 transformer_0/
# EVALUATING SEQUENCES FROM outputs/
# Model: "transformer_encoder_20"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ encoder_20 (Encoder)            │ ?                      │        55,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_148 (Dense)               │ (1, 18)                │           594 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 56,146 (219.32 KB)
#  Trainable params: 56,146 (219.32 KB)
#  Non-trainable params: 0 (0.00 B)
# Running 1 transformer_1/
# EVALUATING SEQUENCES FROM outputs/
# Model: "transformer_encoder_21"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ encoder_21 (Encoder)            │ ?                      │        55,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_153 (Dense)               │ (1, 18)                │           594 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 56,146 (219.32 KB)
#  Trainable params: 56,146 (219.32 KB)
#  Non-trainable params: 0 (0.00 B)
# Running 2 transformer_2/
# EVALUATING SEQUENCES FROM outputs/
# Model: "transformer_encoder_22"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ encoder_22 (Encoder)            │ ?                      │        55,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_158 (Dense)               │ (1, 18)                │           594 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 56,146 (219.32 KB)
#  Trainable params: 56,146 (219.32 KB)
#  Non-trainable params: 0 (0.00 B)
# Running 3 transformer_3/
# EVALUATING SEQUENCES FROM outputs/
# Model: "transformer_encoder_23"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ encoder_23 (Encoder)            │ ?                      │        55,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_163 (Dense)               │ (1, 18)                │           594 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 56,146 (219.32 KB)
#  Trainable params: 56,146 (219.32 KB)
#  Non-trainable params: 0 (0.00 B)
# Running 4 transformer_4/
# EVALUATING SEQUENCES FROM outputs/
# Model: "transformer_encoder_24"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ encoder_24 (Encoder)            │ ?                      │        55,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_168 (Dense)               │ (1, 18)                │           594 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 56,146 (219.32 KB)
#  Trainable params: 56,146 (219.32 KB)
#  Non-trainable params: 0 (0.00 B)
# (5, 7, 18)
# Calculated confidence
# Iterating over MMP1
# writing all scores
# writing all scores
# Iterating over MMP10
# Iterating over MMP11
# Iterating over MMP12
# Iterating over MMP13
# Iterating over MMP14
# Iterating over MMP15
# Iterating over MMP16
# Iterating over MMP17
# Iterating over MMP19
# Iterating over MMP2
# Iterating over MMP20
# Iterating over MMP24
# Iterating over MMP25
# Iterating over MMP3
# Iterating over MMP7
# Iterating over MMP8
# Iterating over MMP9

# %% [markdown]
# The following cells extract data from the prediction model for further analysis

# %%
# Predictions and plots have been saved to the outputs dir, lets look at what is inside these files 

# To get cleavage predictions 
pred_file = os.path.join(save_dir, 'all_scores.csv')
predictions = pd.read_csv(pred_file)
sequences = [seq[1:] for seq in predictions['sequences'].tolist()] # clean model outputs, get rid of extra tokens 
predictions['sequences'] = sequences

# Print z-score predictions 
predictions.head()
# Out:
#     sequences      MMP1     MMP10     MMP11     MMP12     MMP13     MMP14  \
# 0  --AAALS---  0.089758  0.416105  0.395101  0.417816  0.151501  0.177030
# 1  FMPLNFTASG  3.285574  3.171740  2.848731  1.982433  2.459345  1.657082
# 2  LGPYAMTSRG  3.140482  2.308038  2.695278  1.706032  2.480260  2.179934
# 3  AARFKKFATE -0.653065 -0.384744 -0.549065 -0.549792 -0.762877 -0.659807
# 4  AKPNRLVNSY -0.397820 -0.292255 -0.243780  0.316298  0.154016 -0.758081
#
#       MMP15     MMP16     MMP17     MMP19      MMP2     MMP20     MMP24  \
# 0  0.234210  0.239401  1.015474 -0.051086 -0.084090  0.634886  0.163208
# 1  1.633624  1.669429  1.150125  0.990345  2.918436  2.426162  1.772338
# 2  1.696466  2.002263  1.492034  0.693252  3.440998  1.984636  2.076392
# 3 -0.961453 -0.986819 -0.156166  0.445911 -0.466166 -0.208736 -0.936325
# 4 -0.627323 -0.753332  0.444348  0.449070  0.348303  0.192085 -0.638082
#
#       MMP25      MMP3      MMP7      MMP8      MMP9
# 0  1.292107  0.648528  0.674973  0.186854  0.679013
# 1  2.173389  2.123676  1.374689  3.808247  2.432183
# 2  1.580686  2.486686  1.349398  2.749579  2.608290
# 3 -0.405631 -0.042812 -0.653908 -0.798303 -0.099508
# 4  0.001487  0.165671  0.584138  0.031637  0.092842

# %%
# Convert to selectivity scores
selectivity = calc_selectivity_score(mmps, predictions)
selectivity.rename(columns=lambda x:x+'_ss', inplace=True)
selectivity['sequences'] = sequences

# Print selectivity scores 
selectivity.head()
# Out:
#     MMP1_ss  MMP10_ss  MMP11_ss  MMP12_ss  MMP13_ss  MMP14_ss  MMP15_ss  \
# 0 -0.333244  0.012301 -0.009939  0.014112 -0.267868 -0.240838 -0.180295
# 1  1.133106  1.012575  0.670565 -0.246691  0.258274 -0.591180 -0.616019
# 2  1.050469  0.169058  0.579077 -0.468361  0.351411  0.033418 -0.478489
# 3 -0.172112  0.111993 -0.061994 -0.062764 -0.288384 -0.179251 -0.498641
# 4 -0.366470 -0.254695 -0.203368  0.389656  0.217827 -0.747923 -0.609472
#
#    MMP16_ss  MMP17_ss  MMP19_ss   MMP2_ss  MMP20_ss  MMP24_ss  MMP25_ss  \
# 0 -0.174798  0.646926 -0.482373 -0.517318  0.243950 -0.255474  0.939832
# 1 -0.578108 -1.127959 -1.297137  0.744370  0.223139 -0.469145 -0.044503
# 2 -0.154704 -0.694947 -1.540716  1.368662 -0.173368 -0.076215 -0.601080
# 3 -0.525499  0.354017  0.991510  0.025781  0.298354 -0.472034  0.089877
# 4 -0.742894  0.525238  0.530238  0.423543  0.258136 -0.620865  0.056327
#
#     MMP3_ss   MMP7_ss   MMP8_ss   MMP9_ss   sequences
# 0  0.258395  0.286396 -0.230436  0.290674  --AAALS---
# 1 -0.097140 -0.890185  1.686524  0.229514  FMPLNFTASG
# 2  0.358215 -0.845973  0.636572  0.486972  LGPYAMTSRG
# 3  0.474039 -0.173005 -0.325894  0.414007  AARFKKFATE
# 4  0.230168  0.673250  0.088249  0.153055  AKPNRLVNSY

# %%
# To get predicted uncertainty  
pred_file = os.path.join(save_dir, 'all_uncertainty.csv')
uncertainty = pd.read_csv(pred_file)
sequences = [seq[1:] for seq in uncertainty['sequences'].tolist()] # clean model outputs, get rid of extra tokens 
uncertainty['sequences'] = sequences
uncertainty.rename(columns=lambda x:x+'_unc', inplace=True)
uncertainty.rename(columns={'sequences_unc':'sequences'}, inplace=True)

# Print uncertainty predictions 
uncertainty.head()
# Out:
#     sequences  MMP1_unc  MMP10_unc  MMP11_unc  MMP12_unc  MMP13_unc  \
# 0  --AAALS---  0.262109   0.340885   0.273901   0.304532   0.274281
# 1  FMPLNFTASG  0.155442   0.193782   0.158474   0.120033   0.119394
# 2  LGPYAMTSRG  0.250653   0.284855   0.268286   0.158185   0.231395
# 3  AARFKKFATE  0.081461   0.111044   0.149062   0.106750   0.335088
# 4  AKPNRLVNSY  0.054186   0.195143   0.126772   0.184922   0.129664
#
#    MMP14_unc  MMP15_unc  MMP16_unc  MMP17_unc  MMP19_unc  MMP2_unc  MMP20_unc  \
# 0   0.302288   0.298653   0.289559   0.424891   0.169061  0.186358   0.465333
# 1   0.249987   0.108309   0.160417   0.230687   0.210301  0.164949   0.134725
# 2   0.357612   0.341678   0.375396   0.318325   0.277784  0.196136   0.304907
# 3   0.092935   0.229756   0.135304   0.136926   0.169514  0.167405   0.220520
# 4   0.058403   0.143238   0.148128   0.238515   0.226073  0.176992   0.208891
#
#    MMP24_unc  MMP25_unc  MMP3_unc  MMP7_unc  MMP8_unc  MMP9_unc
# 0   0.359177   0.598375  0.289095  0.242053  0.259371  0.346406
# 1   0.199983   0.313814  0.092466  0.098593  0.220759  0.306856
# 2   0.393130   0.504400  0.162542  0.228936  0.212801  0.228025
# 3   0.108881   0.136435  0.202799  0.120205  0.087420  0.225216
# 4   0.096399   0.156046  0.122133  0.225223  0.110016  0.083212

# %% [markdown]
# Using thresholds described in the paper, we can determine if the sequence is likely to be cleaved or not cleaved

# %%
# Looking closer at MMP13, lets look at the distribution of predicted cleavage, selectivity, and uncertainty
mmp_choice = 'MMP7'

mmp_df = predictions[['sequences',mmp_choice]].merge(selectivity[['sequences',mmp_choice+'_ss']], how='outer')
mmp_df = mmp_df.merge(uncertainty[['sequences',mmp_choice+'_unc']], how='outer')

# We can assign a binary cleavage prediction using thresholds determined for each MMP in Table S5 in the paper
z_cutoff = 1.0
mmp_df['Prediction'] = mmp_df[mmp_choice].apply(lambda x: 'Cleaved' if x > z_cutoff else 'Not Cleaved')
mmp_df = mmp_df.sort_values(by=mmp_choice, ascending=False)
mmp_df
# Out:
#     sequences      MMP7   MMP7_ss  MMP7_unc   Prediction
# 3  FMPLNFTASG  1.374689 -0.890185  0.098593      Cleaved
# 4  LGPYAMTSRG  1.349398 -0.845973  0.228936      Cleaved
# 0  --AAALS---  0.674973  0.286396  0.242053  Not Cleaved
# 2  AKPNRLVNSY  0.584138  0.673250  0.225223  Not Cleaved
# 1  AARFKKFATE -0.653908 -0.173005  0.120205  Not Cleaved
# 6  YGPRAVTASG -0.697951 -0.956329  0.465793  Not Cleaved
# 5  SGPRAFWGTA -0.988760 -1.156587  0.184916  Not Cleaved

# %% [markdown]
# ## CleaveNet generations
#
# Design a new set of substrates unconditionally.
#
# To provide a set of z-scores for conditional generation, we recommend using the command line input arguments, and following the example described in the `README.md`, as it requires a customized file format.
#
# Using default values for `temperature` and `repeat_penalty` should be sufficient. To alter the number of generations, change the parameter `num_seqs`

# %%
## ---- Inputs to change ----- ### 

# replace the following with desired parameters

temperature=1 # higher == more diverse, lower == less diverse. We reccomend a range between 0.7 and 1.2 
repeat_penalty=1.2 # higher numbers impose a penalty on repeat AA, a value of 1 is no penalty 
num_seqs = 10 # how many sequences to generate

# %%
from cleavenet.models import simple_inference

# %%
substrate_designs = simple_inference(num_seqs, repeat_penalty, temperature)
# Out:
# Splits previously written to file
# Vocab:
#  {'A': 0, 'C': 1, 'D': 2, 'E': 3, 'F': 4, 'G': 5, 'H': 6, 'I': 7, 'K': 8, 'L': 9, 'M': 10, 'N': 11, 'P': 12, 'Q': 13, 'R': 14, 'S': 15, 'T': 16, 'V': 17, 'W': 18, 'Y': 19, '$': 20, '*': 21}

# %% [markdown]
# The following are sequences designed by CleaveNet:

# %%
print(f'Predicted substrates for: {mmp_choice}')
for substrate in substrate_designs:
    print(' ', substrate)
# Out:
# Predicted substrates for: MMP7
#   MVARALSYEK
#   DILRSLKSWY
#   NLPDPLWDQG
#   AIPASLAMST
#   DPVNHLMDEA
#   TSPVALYSMV
#   LRWSALIDVY
#   TPSNWMAIHW
#   RLPEPLWYEL
#   ISPASLTASG
